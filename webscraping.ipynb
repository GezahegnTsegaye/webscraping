# %%
from bs4 import BeautifulSoup

import requests

# %%
#result = requests.get("http://oreilly.com/store/samplers.html")
result = requests.get("http://www.ebc.et/")

data = result.text

soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #main-content
# /web/guest/home
# #
# /web/en/home
# None
# http://www.ebc.et/web/guest/home
# http://www.ebc.et/web/ebcnews/home
# http://www.ebc.et/web/sport/home
# http://www.ebc.et/web/guest/entertainment
# http://www.ebc.et/web/guest/article
# http://www.ebc.et/web/guest/ebc-tube
# http://www.ebc.et/web/guest/radio
# http://www.ebc.et/web/guest/live
# http://197.156.65.116/
# http://197.156.65.116/fm104.html
# http://197.156.65.116/ebcnational.html
# http://www.ebc.et/web/guest/archive
# http://www.ebc.et/web/guest/-4
# http://www.ebc.et/web/ebcnews/-/--2277
# http://www.ebc.et/web/ebcnews/-/--2276
# http://www.ebc.et/web/ebcnews/-/--2274
# http://www.ebc.et/web/ebcnews/-/--2273
# http://www.ebc.et/web/ebcnews/-/--2272
# http://www.ebc.et/web/ebcnews/-/--2271
# http://www.ebc.et/web/ebcnews/-/--2270
# http://www.ebc.et/web/ebcnews/-/-6-6
# http://www.ebc.et/web/ebcnews/-/7--4
# http://www.ebc.et/web/ebcnews/-/--2267
# http://www.ebc.et/web/ebcnews/-/--2266
# ...
